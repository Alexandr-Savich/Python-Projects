# %%
import pandas as pd
import numpy as np

# %%
df_b = pd.read_csv('https://docs.google.com/spreadsheets/d/1Tc_aiVXrCrMNQFFDMiJGQ3Gm35szGLps_FIsonCe38Q/export?gid=0&format=csv')
df_s = pd.read_csv('https://docs.google.com/spreadsheets/d/1Tc_aiVXrCrMNQFFDMiJGQ3Gm35szGLps_FIsonCe38Q/export?gid=720312140&format=csv')
df_p = pd.read_csv('https://docs.google.com/spreadsheets/d/1Tc_aiVXrCrMNQFFDMiJGQ3Gm35szGLps_FIsonCe38Q/export?gid=41907226&format=csv')

# %%
df_b.dropna(thresh = 2, inplace = True, axis = 0)
df_b.dropna(thresh = 2, inplace = True, axis = 1)
df_s.dropna(thresh = 2, inplace = True, axis = 0)
df_s.dropna(thresh = 2, inplace = True, axis = 1)
df_p.dropna(thresh = 2, inplace = True, axis = 0)
df_p.dropna(thresh = 2, inplace = True, axis = 1)

df_b.drop(axis = 0, labels = [66,67,68], inplace = True)
df_s.drop(axis = 0, labels = [66,67,68], inplace = True)
df_p.drop(axis = 0, labels = [66,67,68], inplace = True)

# %%
df_p.isnull().sum()
# Out:
# Country                                             0
# Premium                                             0
# Currency                                            0
# Unnamed: 3                                          0
# Price USD                                           0
# # of TV Shows                                       0
# # of Movies                                         0
# Average Total Library Size                          0
# Price per Title                                     0
# % Difference (Cost per Month) to Average            0
# % Difference (Cost Per Month) to Most Expensive     0
# % Difference (Cost Per Month) to Cheapest           0
# % Difference (Cost per Title) to Average            0
# % Difference (Cost per Title)  to Most Expensive    0
# % Difference (Cost per Title)  to Cheapest          0
# dtype: int64

# %%
sum(df_b['Country'] == 'Czech Republic')
# Out:
# 1

# %% [markdown]
# Данные почищенны

# %%
income = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSM55rJybigco-_uoc1BECnvz5C_GqhXN6-eck5Y2-xJeoM1PM3idl3CFP7jNYrHxiofUHrobE0UR3k/pub?gid=1401346660&single=true&output=csv')

# %%
df_b = df_b.merge(income)
df_s = df_s.merge(income)
df_p = df_p.merge(income)

# %%
df_b.corr()['Salary']
# Out:
# Basic                                              -0.148281
# Price USD                                           0.623407
# # of TV Shows                                       0.011310
# # of Movies                                        -0.010952
# Total Library Size                                  0.004685
# Price per Title                                     0.403471
# % Difference (Cost per Month) to Average           -0.529910
# % Difference (Cost Per Month) to Most Expensive    -0.552592
# % Difference (Cost Per Month) to Cheapest          -0.449270
# % Difference (Cost per Title) to Average           -0.423714
# % Difference (Cost per Title)  to Most Expensive   -0.423300
# % Difference (Cost per Title)  to Cheapest         -0.399734
# Salary                                              1.000000
# Name: Salary, dtype: float64

# %%
df_s.corr()['Salary']
# Out:
# Standard                                           -0.152302
# Price USD                                           0.723485
# # of TV Shows                                       0.011310
# # of Movies                                        -0.010952
# Total Library Size                                  0.004685
# Price per Title                                     0.470035
# % Difference (Cost per Month) to Average           -0.642370
# % Difference (Cost Per Month) to Most Expensive    -0.669014
# % Difference (Cost Per Month) to Cheapest          -0.552448
# % Difference (Cost per Title) to Average           -0.504960
# % Difference (Cost per Title)  to Most Expensive   -0.498280
# % Difference (Cost per Title)  to Cheapest         -0.486454
# Salary                                              1.000000
# Name: Salary, dtype: float64

# %%
df_p.corr()['Salary']
# Out:
# Premium                                            -0.155844
# Price USD                                           0.735797
# # of TV Shows                                       0.011310
# # of Movies                                        -0.010952
# Average Total Library Size                          0.004685
# Price per Title                                     0.490956
# % Difference (Cost per Month) to Average           -0.670037
# % Difference (Cost Per Month) to Most Expensive    -0.692779
# % Difference (Cost Per Month) to Cheapest          -0.589416
# % Difference (Cost per Title) to Average           -0.530123
# % Difference (Cost per Title)  to Most Expensive   -0.522953
# % Difference (Cost per Title)  to Cheapest         -0.512209
# Salary                                              1.000000
# Name: Salary, dtype: float64

# %%
df_b
# Out:
#           Country     Basic Currency Unnamed: 3  Price USD  # of TV Shows  \
# 0          Turkey     26.99      TRY        USD       1.97         2930.0
# 1           India    199.00      INR        USD       2.64         3718.0
# 2       Argentina    379.00      ARS        USD       3.74         3154.0
# 3        Colombia  16900.00      COP        USD       4.31         3156.0
# 4          Brazil     25.90      BRL        USD       4.61         3162.0
# ..            ...       ...      ...        ...        ...            ...
# 60         Sweden     99.00      SEK        USD      10.90         2973.0
# 61        Denmark     79.00      DKK        USD      12.00         2978.0
# 62     San Marino      7.99      EUR        USD       9.03         1937.0
# 63        Croatia      7.99      EUR        USD       9.03         1675.0
# 64  Liechtenstein     11.90      CHF        USD      12.88         1712.0
#
#     # of Movies  Total Library Size  Price per Title  \
# ...

# %% [markdown]
# Как видим, наблюдается значительная положительная корреляция  дохода и цены подписки по странам, причем наиболее выражено это для премиум подписки.

# %% [markdown]
# Ниже scatterplot цена/зарплата

# %%
df_b.plot('Price USD', 'Salary', kind = 'scatter', color = 'green')
# Out:
# <AxesSubplot:xlabel='Price USD', ylabel='Salary'>

# %%
df_s.plot('Price USD', 'Salary', kind = 'scatter', color = 'green')
# Out:
# <AxesSubplot:xlabel='Price USD', ylabel='Salary'>

# %%
df_p.plot('Price USD', 'Salary', kind = 'scatter', color = 'green')
# Out:
# <AxesSubplot:xlabel='Price USD', ylabel='Salary'>

# %%
df_b.groupby('Currency')['Price USD'].mean().sort_values(ascending = False).plot.bar(color = ['green', 'red', 'blue', 'purple'])
# Out:
# <AxesSubplot:xlabel='Currency'>

# %%
df_s.groupby('Currency')['Price USD'].mean().sort_values(ascending = False).plot.bar(color = ['green', 'red', 'blue', 'purple'])
# Out:
# <AxesSubplot:xlabel='Currency'>

# %%
df_p.groupby('Currency')['Price USD'].mean().sort_values(ascending = False).plot.bar(color = ['green', 'red', 'blue', 'purple'])
# Out:
# <AxesSubplot:xlabel='Currency'>

# %%
continents = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSM55rJybigco-_uoc1BECnvz5C_GqhXN6-eck5Y2-xJeoM1PM3idl3CFP7jNYrHxiofUHrobE0UR3k/pub?gid=2029349297&single=true&output=csv')

# %%
df_b = df_b.merge(continents,'left' )
df_s = df_s.merge(continents,'left')
df_p = df_p.merge(continents,'left')

# %%
df_b.fillna('Europe', inplace = True)
df_s.fillna('Europe', inplace = True)
df_p.fillna('Europe', inplace = True)

# %% [markdown]
# Диаграммы подписка/континент

# %%
df_b.groupby('Continent')['Price USD'].mean().sort_values(ascending = False).plot.bar(color = ['green', 'red', 'blue', 'purple'])
# Out:
# <AxesSubplot:xlabel='Continent'>

# %%
df_s.groupby('Continent')['Price USD'].mean().sort_values(ascending = False).plot.bar(color = ['green', 'red', 'blue', 'purple'])
# Out:
# <AxesSubplot:xlabel='Continent'>

# %%
df_p.groupby('Continent')['Price USD'].mean().sort_values(ascending = False).plot.bar(color = ['green', 'red', 'blue', 'purple'])
# Out:
# <AxesSubplot:xlabel='Continent'>

# %% [markdown]
# Сколько стоит подписка относительно среднего дохода (базовая, стандартная, премиум) в Чехии?

# %%
df_b
# Out:
#           Country     Basic Currency Unnamed: 3  Price USD  # of TV Shows  \
# 0          Turkey     26.99      TRY        USD       1.97         2930.0
# 1           India    199.00      INR        USD       2.64         3718.0
# 2       Argentina    379.00      ARS        USD       3.74         3154.0
# 3        Colombia  16900.00      COP        USD       4.31         3156.0
# 4          Brazil     25.90      BRL        USD       4.61         3162.0
# ..            ...       ...      ...        ...        ...            ...
# 60         Sweden     99.00      SEK        USD      10.90         2973.0
# 61        Denmark     79.00      DKK        USD      12.00         2978.0
# 62     San Marino      7.99      EUR        USD       9.03         1937.0
# 63        Croatia      7.99      EUR        USD       9.03         1675.0
# 64  Liechtenstein     11.90      CHF        USD      12.88         1712.0
#
#     # of Movies  Total Library Size  Price per Title  \
# ...

# %%
df_b['Ratio'] = df_b['Price USD'] / df_b['Salary']
df_s['Ratio'] = df_s['Price USD'] / df_s['Salary']
df_p['Ratio'] = df_p['Price USD'] / df_p['Salary']

# %%
df_p.where(df_b['Country'] == 'Czech Republic').dropna()
# Out:
#       Country  Premium Currency Unnamed: 3  Price USD  # of TV Shows  \
# 10  Lithuania    11.99      EUR        USD      13.54         4490.0
#
#     # of Movies  Average Total Library Size  Price per Title  \
# 10       1972.0                      6462.0          0.00052
#
#     % Difference (Cost per Month) to Average  \
# 10                                     14.82
#
#     % Difference (Cost Per Month) to Most Expensive  \
# 10                                            66.23
#
#     % Difference (Cost Per Month) to Cheapest  \
# 10                                    -108.42
#
#     % Difference (Cost per Title) to Average  \
# 10                                     39.18
#
#     % Difference (Cost per Title)  to Most Expensive  \
# 10                                            123.36
#
#     % Difference (Cost per Title)  to Cheapest   Salary Continent     Ratio
# 10                                      -82.96  1063.97    Europe  0.012726

# %%
CZR = \
[df_b.where(df_b['Country'] == 'Czech Republic').dropna()['Ratio'],
 df_s.where(df_s['Country'] == 'Czech Republic').dropna()['Ratio'],
 df_p.where(df_p['Country'] == 'Czech Republic').dropna()['Ratio']]

# %% [markdown]
# Как видим, искомые величины составляют 0.7%, 0.8% и 1%

# %%
CZR
# Out:
# [10    0.006649
#  Name: Ratio, dtype: float64,
#  7    0.008652
#  Name: Ratio, dtype: float64,
#  4    0.010655
#  Name: Ratio, dtype: float64]

# %% [markdown]
# Какие топ-5 стран имеют самую большую доступную коллекцию сериалов?

# %%
df_b.sort_values(by=['# of Movies'], ascending=False).head(5)['Country']
# Out:
# 18          Malaysia
# 8        Philippines
# 28         Singapore
# 1              India
# 9     United Kingdom
# Name: Country, dtype: object

# %% [markdown]
# Какой процент среднего дохода россиянина будет составлять подписка Netflix?

# %%
RSA = \
[df_b.where(df_b['Country'] == 'Russia').dropna()['Ratio'],
 df_s.where(df_s['Country'] == 'Russia').dropna()['Ratio'],
 df_p.where(df_p['Country'] == 'Russia').dropna()['Ratio']]

# %%
RSA
# Out:
# [25    0.015008
#  Name: Ratio, dtype: float64,
#  17    0.020011
#  Name: Ratio, dtype: float64,
#  17    0.025032
#  Name: Ratio, dtype: float64]

# %% [markdown]
# 1.5, 2, 2.5 процента соответсвенно

# %% [markdown]
# На каком месте будет Россия, если отсортировать страны по эффективности подписки (Cost Per Title)

# %%
df_b.sort_values(by=['Price per Title'], ascending = False).where(df_b['Country'] == 'Russia').dropna()
# Out:
#    Country  Basic Currency Unnamed: 3  Price USD  # of TV Shows  # of Movies  \
# 25  Russia  599.0      RUB        USD       8.13         3624.0       2087.0
#
#     Total Library Size  Price per Title  \
# 25              5711.0          0.00142
#
#     % Difference (Cost per Month) to Average  \
# 25                                      3.08
#
#     % Difference (Cost Per Month) to Most Expensive  \
# 25                                            45.26
#
#     % Difference (Cost Per Month) to Cheapest  \
# 25                                    -121.84
#
#     % Difference (Cost per Title) to Average  \
# 25                                     15.56
#
#     % Difference (Cost per Title)  to Most Expensive  \
# 25                                             99.24
#
#     % Difference (Cost per Title)  to Cheapest  Salary Continent     Ratio
# 25                                     -107.94  541.71    Europe  0.015008

# %%
df_s.sort_values(by=['Price per Title']).where(df_s['Country'] == 'Russia').dropna()
# Out:
#    Country  Standard Currency Unnamed: 3  Price USD  # of TV Shows  \
# 17  Russia     799.0      RUB        USD      10.84         3624.0
#
#     # of Movies  Total Library Size  Price per Title  \
# 17       2087.0              5711.0          0.00095
#
#     % Difference (Cost per Month) to Average  \
# 17                                     10.72
#
#     % Difference (Cost Per Month) to Most Expensive  \
# 17                                            61.45
#
#     % Difference (Cost Per Month) to Cheapest  \
# 17                                    -113.36
#
#     % Difference (Cost per Title) to Average  \
# 17                                     23.05
#
#     % Difference (Cost per Title)  to Most Expensive  \
# 17                                            111.81
#
#     % Difference (Cost per Title)  to Cheapest  Salary Continent     Ratio
# 17                                      -98.42  541.71    Europe  0.020011

# %%
df_p.sort_values(by=['Price per Title']).where(df_p['Country'] == 'Russia').dropna()
# Out:
#    Country  Premium Currency Unnamed: 3  Price USD  # of TV Shows  \
# 17  Russia    999.0      RUB        USD      13.56         3624.0
#
#     # of Movies  Average Total Library Size  Price per Title  \
# 17       2087.0                      5711.0          0.00059
#
#     % Difference (Cost per Month) to Average  \
# 17                                     14.74
#
#     % Difference (Cost Per Month) to Most Expensive  \
# 17                                            66.15
#
#     % Difference (Cost Per Month) to Cheapest  \
# 17                                    -108.48
#
#     % Difference (Cost per Title) to Average  \
# 17                                     27.09
#
#     % Difference (Cost per Title)  to Most Expensive  \
# 17                                            115.36
#
#     % Difference (Cost per Title)  to Cheapest  Salary Continent     Ratio
# 17                                      -92.99  541.71    Europe  0.025032

# %% [markdown]
# Таким образом 25, 17 и 17 места

# %% [markdown]
# В какой стране лучше всего брать VPN для того, чтобы платить за Netflix меньше всего?

# %%
df_b.sort_values(by=['Price USD']).head()
# Out:
#      Country     Basic Currency Unnamed: 3  Price USD  # of TV Shows  \
# 0     Turkey     26.99      TRY        USD       1.97         2930.0
# 1      India    199.00      INR        USD       2.64         3718.0
# 2  Argentina    379.00      ARS        USD       3.74         3154.0
# 3   Colombia  16900.00      COP        USD       4.31         3156.0
# 4     Brazil     25.90      BRL        USD       4.61         3162.0
#
#    # of Movies  Total Library Size  Price per Title  \
# 0       1709.0              4639.0          0.00043
# 1       2125.0              5843.0          0.00045
# 2       1606.0              4760.0          0.00079
# 3       1835.0              4991.0          0.00086
# 4       1810.0              4972.0          0.00093
#
#    % Difference (Cost per Month) to Average  \
# 0                                    123.76
# 1                                    104.19
# 2                                     76.63
# 3                                     64.12
# ...

# %%
df_s.sort_values(by=['Price USD']).head()
# Out:
#      Country  Standard Currency Unnamed: 3  Price USD  # of TV Shows  \
# 0     Turkey     40.99      TRY        USD       3.00         2930.0
# 2  Argentina    639.00      ARS        USD       6.30         3154.0
# 1      India    499.00      INR        USD       6.61         3718.0
# 3   Colombia  26900.00      COP        USD       6.86         3156.0
# 4     Brazil     39.90      BRL        USD       7.11         3162.0
#
#    # of Movies  Total Library Size  Price per Title  \
# 0       1709.0              4639.0          0.00032
# 2       1606.0              4760.0          0.00066
# 1       2125.0              5843.0          0.00057
# 3       1835.0              4991.0          0.00069
# 4       1810.0              4972.0          0.00071
#
#    % Difference (Cost per Month) to Average  \
# 0                                    120.42
# 2                                     62.79
# 1                                     58.47
# 3                                     55.00
# ...

# %%
df_p.sort_values(by=['Price USD']).head()
# Out:
#      Country   Premium Currency Unnamed: 3  Price USD  # of TV Shows  \
# 0     Turkey     54.99      TRY        USD       4.02         2930.0
# 1      India    649.00      INR        USD       8.60         3718.0
# 5  Argentina    939.00      ARS        USD       9.26         3154.0
# 6   Colombia  38900.00      COP        USD       9.93         3156.0
# 9     Brazil     55.90      BRL        USD       9.96         3162.0
#
#    # of Movies  Average Total Library Size  Price per Title  \
# 0       1709.0                      4639.0          0.00022
# 1       2125.0                      5843.0          0.00037
# 5       1606.0                      4760.0          0.00049
# 6       1835.0                      4991.0          0.00050
# 9       1810.0                      4972.0          0.00050
#
#    % Difference (Cost per Month) to Average  \
# 0                                    118.48
# 1                                     58.51
# 5                                     51.67
# ...

# %% [markdown]
# Таким образом, самая дешевая подписка в Турции, а самая дорогая в Лихтенштейне, значит в нем брать VPN и через Турцию

# %%
df_b.sort_values(by=['Price USD']).tail()
# Out:
#           Country  Basic Currency Unnamed: 3  Price USD  # of TV Shows  \
# 50         Israel   32.9      ILS        USD      10.56         3650.0
# 60         Sweden   99.0      SEK        USD      10.90         2973.0
# 61        Denmark   79.0      DKK        USD      12.00         2978.0
# 59    Switzerland   11.9      CHF        USD      12.88         3654.0
# 64  Liechtenstein   11.9      CHF        USD      12.88         1712.0
#
#     # of Movies  Total Library Size  Price per Title  \
# 50       2063.0              5713.0          0.00185
# 60       1388.0              4361.0          0.00250
# 61       1580.0              4558.0          0.00263
# 59       1852.0              5506.0          0.00234
# 64       1336.0              3048.0          0.00423
#
#     % Difference (Cost per Month) to Average  \
# 50                                    -22.96
# 60                                    -26.07
# 61                                    -35.51
# ...

# %%
df_s.sort_values(by=['Price USD']).tail()
# Out:
#           Country  Standard Currency Unnamed: 3  Price USD  # of TV Shows  \
# 56        Belgium     13.49      EUR        USD      15.24         3374.0
# 48  United States     15.49      USD        USD      15.49         3826.0
# 57         Israel     54.90      ILS        USD      17.62         3650.0
# 61    Switzerland     18.90      CHF        USD      20.46         3654.0
# 64  Liechtenstein     18.90      CHF        USD      20.46         1712.0
#
#     # of Movies  Total Library Size  Price per Title  \
# 56       1616.0              4990.0          0.00153
# 48       1992.0              5818.0          0.00133
# 57       2063.0              5713.0          0.00154
# 61       1852.0              5506.0          0.00186
# 64       1336.0              3048.0          0.00336
#
#     % Difference (Cost per Month) to Average  \
# 56                                    -23.20
# 48                                    -24.81
# 57                                    -37.38
# ...

# %%
df_p.sort_values(by=['Price USD']).tail()
# Out:
#           Country  Premium Currency Unnamed: 3  Price USD  # of TV Shows  \
# 38        Ireland    17.99      EUR        USD      20.32         4515.0
# 53          Spain    17.99      EUR        USD      20.32         3536.0
# 56         Israel    69.90      ILS        USD      22.43         3650.0
# 61    Switzerland    24.90      CHF        USD      26.96         3654.0
# 64  Liechtenstein    24.90      CHF        USD      26.96         1712.0
#
#     # of Movies  Average Total Library Size  Price per Title  \
# 38       1971.0                      6486.0          0.00078
# 53       1693.0                      5229.0          0.00097
# 56       2063.0                      5713.0          0.00098
# 61       1852.0                      5506.0          0.00122
# 64       1336.0                      3048.0          0.00221
#
#     % Difference (Cost per Month) to Average  \
# 38                                    -25.58
# 53                                    -25.58
# ...
